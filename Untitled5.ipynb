# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
# load dataset
data = pd.read_csv("resume.csv")
# display dataset
print(data)
# input and output
X = data['Resume']
y = data['Result']
# convert text into numbers
vectorizer = CountVectorizer()
X_vector = vectorizer.fit_transform(X)
# create model
model = MultinomialNB()
# train model
model.fit(X_vector, y)
# test resume
test = ["Python SQL"]
# convert test text
test_vector = vectorizer.transform(test)
# prediction
prediction = model.predict(test_vector)
# output
print("Prediction:", prediction[0])
# graph
data['Result'].value_counts().plot(kind='bar')
plt.title("Resume Screening Results")
plt.xlabel("Result")
plt.ylabel("Count")
plt.show()
# Out:
#                      Resume    Result
# 0           Python Java SQL  Selected
# 1   Machine Learning Python  Selected
# 2       HTML CSS JavaScript  Selected
# 3          Cooking Painting  Rejected
# 4           Dancing Singing  Rejected
# 5       Data Science Python  Selected
# 6  Communication Leadership  Rejected
# 7        Java Developer SQL  Selected
# Prediction: Selected
